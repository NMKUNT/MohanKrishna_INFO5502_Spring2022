# %% [markdown]
# <a href="https://colab.research.google.com/github/NMKUNT/MohanKrishna_INFO5502_Spring2022/blob/main/lab_assignment_03_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The third Lab-assignment (02/10/2022, 50 points in total)

# %% [markdown]
# The purpose of this exercise is to understand users' information needs, then collect data from different sources for analysis.

# %% [markdown]
# Question 1 (10 points). Fomulate your domain problem: Describe an interesting research question (or practical question) you have in mind, what kind of data should be collected to answer the question(s)? How many data needed for the analysis? The detail steps for collecting and save the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
I wanted to collect data of all the televisions on sale in any of the websites. So, I have chosen Flipkart as my base,
as it contains multiple products from different brands. Now to retrieve data, I used web scrapping
to collect details of televisions, which include Product name, Price, dicount we are gonna get, what is the overall rating by the buyers
and the page number on which the item is located. I used BeautifulSoup, to read the HTML tags of the website. 'requests' helped me to read the data
from the URL. As all the products were not listed on the same page, I used 'for' loop to collect products from all the pages.
I found that there were around 1000 products, which is a good number. I used pandas to formulate the data in to a table, and then exported the
data in to an excel sheet using 'to_csv'. Now, I can directly open the excelsheet to view all the products easily instead of waiting for the 
pages to load.


'''
# Out:
# "\nI wanted to collect data of all the televisions on sale in any of the websites. So, I have chosen Flipkart as my base,\nas it contains multiple products from different brands. To analyze this data excel sheet is the best option. So, I used web scrapping\nto collect details of televisions, which include Product name, Price, dicount we are gonna get, what is the overall rating by the buyers\nand the page number on which the item is located. I used BeautifulSoup, to read the HTML tags of the website. 'requests' helped me to read the data\nI found that there were around 1000 products, which is a good number. I used pandas to formulate the data in to a table, and then exported the\ndata in to an excel sheet. Now, I can directly open the excelsheet to view all the products easily instead of waiting for the pages to load.\n\n\n"

# %% [markdown]
# Question 2 (10 points). Collect your data to answer the research problem: Write python code to collect 1000 data samples you discussed above.

# %%
# You code here (Please add comments in the code):


import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time

# %%
tv_name = [] 
tv_cost = []
tv_rating = []
discount = []
pg_num = []
count = 0
for i in range(1,42): # goes through the 41 pages
    start_time = time.time()
    URL = 'https://www.flipkart.com/search?q=TV&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={}'.format(i)
    page = requests.get(URL)
    pagecontent = page.text
    soup = BeautifulSoup(pagecontent)
    count = count+1
    for x in soup.find_all('div', attrs={'class':'_3pLy-c row'}): #Gets data of all the televisions on the current page
        tele_name = x.find('div', attrs = {'class':'_4rR01T'})
        tele_cost = x.find('div', attrs = {'class':'_30jeq3 _1_WHN1'})
        tele_rating = x.find('div', attrs = {'class':'_3LWZlK'})
        disc = x.find('div', attrs = {'class':'_3Ay6Sb'})
        
        
        if tele_name is None:
            tv_name.append(np.NaN)
        else:
            tv_name.append(tele_name.text)
            
        if tele_cost is None:
            tv_cost.append(np.NaN)
        else:
            tv_cost.append(tele_cost.text[1:])
            
        if tele_rating is None:
            tv_rating.append(np.NaN)
        else:
            tv_rating.append(tele_rating.text)
        if disc is None:
            discount.append(np.NaN)
        else:
            discount.append(disc.text)
        
        
        pg_num.append(i)
        
print("Data collected from ",count," pages")
# Out:
# Data collected from  41  pages

# %%
television_df = pd.DataFrame({'TV Name':tv_name, 'TV Cost':tv_cost, 'TV Rating': tv_rating, 'Discount':discount, 'Page number': pg_num})

# %%
television_df.to_csv(r'Downloads\TelevisionInfo.csv')

# %%
television_df.head(1000)
# Out:
#                                                TV Name  ... Page number
# 0          Adsun 80 cm (32 inch) HD Ready LED Smart TV  ...           1
# 1    Hisense U80G Series 189 cm (75 inch) QLED Ultr...  ...           1
# 2    realme 80 cm (32 inch) HD Ready LED Smart Andr...  ...           1
# 3             LG 80 cm (32 inch) HD Ready LED Smart TV  ...           1
# 4        SAMSUNG 80 cm (32 inch) HD Ready LED Smart TV  ...           1
# ..                                                 ...  ...         ...
# 979  Hisense A6GE 126 cm (50 inch) Ultra HD (4K) LE...  ...          41
# 980            Daiwa 80 cm (31.5 inch) HD Ready LED TV  ...          41
# 981           RGL 80 cm (32 inch) Full HD LED Smart TV  ...          41
# 982            SAMSUNG 100 cm (40 inch) Full HD LED TV  ...          41
# 983  KODAK CA Series 189 cm (75 inch) Ultra HD (4K)...  ...          41
#
# [984 rows x 5 columns]

# %% [markdown]
# Question 3 (10 points). Understand the data quality: Search a second hand dataset (any dataset) from kaggle or other websites. Describe the data quality problem of the dataset and explain your strtegy to clean the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):
'''
I have reviewed a dataset related to farming.I found this dataset in kaggle. It contains parameters like crop type,temperature, 
humidity, water content, pH. This data is used to predict the type of crop suitable to grow and will suggest actions
to be taken while the crop grow. 

The dataset that they used had two problems. 
1- It has some data in capitals, some in small and few combined. This can be overcome by changing all the letters to lower case or upper case.
2- It has some missing values. This can be solved by replacing null to NaN. The missing data can be visualized using heatmap.

some other which can arise in a dataset can be :
1- irrelavent data. Dataset may contain multiple columns, But we might need only few of them to analyse our problem. So, retrieving only
the required will help us to analyse efficiently.
2- Duplicates. As the data is collected from various sources and people, there are high chances of having duplicate values of our data.
   Using Pandas (DataFrame.drop_duplicates), we can remove the duplicates from our dataset.
3- incorrect datatypes. Need to check if a column is in correct datatype. For example, if a numeric value column has a datatype of string.
   So, for such columns, we need to change the datatype.
   
'''

# %% [markdown]
# Question 4 (20 points). Data cleaning: There are two datasets TwADR-L (from Twitter) and AskAPatient (Link: https://zenodo.org/record/55013#.YgU2NN-ZO4T) for medical concept
# normalization. However, the two datasets have serious data quality problems. Please read the introduction of the datasets and clean the two datasets by following the steps in the statement.
#
# In the original dataset, the TwADR-L had 48,057 training, 1,256 validation and 1,427 test examples. The test set (all
# test samples from 10 folds combined) consists of 765 unique phrases and 273 unique classes (medical concepts). The AskAPatient dataset contained 156,652 training, 7,926 validation, and 8,662 test examples. The entire test set (all test samples
# from 10 folds combined) consists of 3,749 unique phrases and 1,035 unique classes (medical concepts). The authors
# randomly split each dataset into ten equal folds, ran 10-fold cross validation and reported the accuracy averaged across the
# ten folds.
#
# We found that, in the original data set, many phrase-label pairs appeared multiple times within the same training data file
# and also across the training and test data sets in the same fold. In the AskAPatient data set, on average 35.82% of the test data overlapped with training data in the same fold. In the Twitter (TwADR-L) dataset, on average 8.62% of the test set had an overlap with the training data in the same fold. Having a large overlap between the training and the test data can potentially
# introduce bias in the model and contribute to high accuracy. It is not unlikely that the high model performance reported in the original paper may be triggered by the the large overlap between the training and test sets.
#
# Therefore to remove the bias, we further cleaned and recreated the training, validation, and test sets such that each
# phrase-label pair appears only once in the entire dataset (either in training, validation or test set).
#
# (1) First, we combined all examples in training, validation and test data from the original data set and then removed all
# duplicate phrase-label pairs (examples that have the same phrase and label pair and appear more than once in training/validation/test datasets). Table II shows the statistics of the new dataset (after removing duplicates). The Twitter data set had 3,157 unique phrase-label pairs and 2,220 unique labels (medical concepts) while 173 phrases had multiple labels (i.e., they were assigned to more than one label). Many concepts had only one example, and the concept that had the most number
# of examples had 36 phrases. On average, each concept had 1.42 examples. The AskAPatient data set had 4,496 unique phrase-label pairs, 1,036 unique labels while 26 phrases had multiple labels. Table III shows examples of phrases that had multiple labels. For example, ‘mad’ can be mapped to ‘anger’ or ‘rage’ and ‘sore’ can be mapped to ‘pain’ or ‘myalgia’.
#
# (2) Second, we remove all concepts that had less than five examples. The statistics of the final data are shown in Table IV.
#
# (3) Third, we divide all examples without multiple labels into random 10 folds such that each unique phrase-label pair
# appears once in one of the 10 test sets. We add the pairs with multiple labels into the training data. This final 10-folds
# dataset is used in all our experiments.
#
# (The original paper can be download on canvas)

# %%
import glob
import requests
from bs4 import BeautifulSoup
import numpy as np
import time
import pandas as pd
import csv

# %%
# !unzip /content/sample_data/datasets.zip
# Out:
# Archive:  /content/sample_data/datasets.zip
# replace datasets/.DS_Store? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: datasets/.DS_Store
#   inflating: __MACOSX/datasets/._.DS_Store
#   inflating: datasets/AskAPatient/AskAPatient.fold-0.test.txt
#   inflating: __MACOSX/datasets/AskAPatient/._AskAPatient.fold-0.test.txt
#   inflating: datasets/AskAPatient/AskAPatient.fold-0.train.txt
#   inflating: __MACOSX/datasets/AskAPatient/._AskAPatient.fold-0.train.txt
#   inflating: datasets/AskAPatient/AskAPatient.fold-0.validation.txt
#   inflating: __MACOSX/datasets/AskAPatient/._AskAPatient.fold-0.validation.txt
#   inflating: datasets/AskAPatient/AskAPatient.fold-1.test.txt
#   inflating: __MACOSX/datasets/AskAPatient/._AskAPatient.fold-1.test.txt
#   inflating: datasets/AskAPatient/AskAPatient.fold-1.train.txt
#   inflating: __MACOSX/datasets/AskAPatient/._AskAPatient.fold-1.train.txt
#   inflating: datasets/AskAPatient/AskAPatient.fold-1.validation.txt
# ...

# %%
import glob
final=  pd.DataFrame()
# defining some functions to make our code look simple and easy to use 
def lettercasechange(df): # this functions helps us to change the all the letters to lower case
    for col in df_mn.columns:
        df_mn[col] = df_mn[col].str.lower()
    return(df)
def duplicates(df): # we will be dropping the duplicates
    df = df.drop_duplicates('phrase-label')
    return(df)

for dataset in ['TwADR-L', 'AskAPatient']: #  we are gonna read all the files in the subfolders
    newset = {}
    df_mn = pd.DataFrame()
    for filepath in glob.glob('/content/datasets/{}/*.txt'.format(dataset)): # glob helps to return all file paths that match a specific pattern.
        data = pd.read_csv(filepath, sep = "\t", header = None, encoding= 'unicode_escape')  # this retrieves data from the csv file
        df_mn = df_mn.append(data) # we are appending data read from the all the files 
        
    df_mn = df_mn.reset_index(drop=True)  # resetting the index of our data frame
    df_mn['phrase_label'] = df_mn[1] + " " + df_mn[2] 
    df_mn.columns = ['id', 'label_name', 'phrases_name', 'phrase-label']
    df_mn = df_mn.astype({"id": str})  # changes the data type to string

    df_mn = lettercasechange(df_mn)
    df_mn = duplicates(df_mn)

    # creating a table of values

    newset['Unique Phrases'] = str(len(df_mn['phrases_name'].unique())) #unique function makes our task simple by returning the count of unique values
    newset['Unique Labels'] = str(len(df_mn['label_name'].unique()))
    newset['Unique Phrase/Label Pairs'] = str(df_mn.shape[0])
    df_mn1 = pd.DataFrame(df_mn['phrases_name'].value_counts())
    newset['Phrases (multiple labels)'] = str(df_mn1[df_mn1['phrases_name'] > 1].shape[0])
    newset['Minimum examples/label'] = str(df_mn['label_name'].value_counts().values.min()) # min function
    newset['Maximum examples/label'] = str(df_mn['label_name'].value_counts().values.max()) # max function
    newset['Average examples/label'] = round(df_mn['label_name'].value_counts().mean(),2) # mean function gives the average
    final = final.append(newset, ignore_index=True) # appening data from all the folders 
	
final = final.T
final.columns = ['TwADR-L', 'AskAPatient']
final
# Out:
#                           TwADR-L AskAPatient
# Unique Phrases               2944        4470
# Unique Labels                2220        1038
# Unique Phrase/Label Pairs    3157        4507
# Phrases (multiple labels)     173          35
# Minimum examples/label          1           1
# Maximum examples/label         36         141
# Average examples/label       1.42        4.34

# %%
final_1 = pd.DataFrame()
def storedata(df):
    index_list = []
    for i in range(df.shape[0]):
        if df['label_name'].value_counts()[df.iloc[i]['label_name']] < 5:
            index_list.append(i)
    dropdata(index_list,df)#calling the funtion in the function to drop the data which is stored
def dropdata(df,df1):
    # we are removing the data lable which are less than 5
    df1.drop(df1.index[df], inplace=True)
# we iterate through both datasets 
for dataset in ['TwADR-L', 'AskAPatient']:
    df_mn = pd.DataFrame()
    for filepath in glob.glob('/content/datasets/{}/*.txt'.format(dataset)):
        data = pd.read_csv(filepath, sep = "\t", header = None, encoding= 'unicode_escape')
        df_mn = df_mn.append(data)
    # we combine by the two data set text files
    df_mn = df_mn.reset_index(drop=True)
    df_mn['phrase_label'] = df_mn[1] + "-" + df_mn[2]
    df_mn.columns = ['id', 'label_name', 'phrases_name', 'phrase-label']
    df_mn = df_mn.astype({"id": str})
    # converting to lower case so while checking we remove all the duplicates correctly 
    for col in df_mn.columns:
        df_mn[col] = df_mn[col].str.lower() 
    # we are removing the duplicates
    df_mn = duplicates(df_mn)
    storedata(df_mn)#calling function to store data
    newset = {}
    # storing newsets of the table in dictionary
    newset['Unique Phrases'] = str(len(df_mn['phrases_name'].unique()))
    newset['Unique Labels'] = str(len(df_mn['label_name'].unique()))
    newset['Unique Phrase/Label Pairs'] = str(df_mn.shape[0])
    df_mn1 = pd.DataFrame(df_mn['phrases_name'].value_counts())
    newset['Phrases (multiple labels)'] = str(df_mn1[df_mn1['phrases_name'] > 1].shape[0])
    newset['Minimum examples/label'] = str(df_mn['label_name'].value_counts().values.min())
    newset['Maximum examples/label'] = str(df_mn['label_name'].value_counts().values.max())
    newset['Average examples/label'] = round(df_mn['label_name'].value_counts().mean(), 2)
    # appending dictinary to dataframe
    final_1 = final_1.append(newset, ignore_index=True)
final_1 = final_1.T
final_1.columns = ['TwADR-L', 'AskAPatient']
final_1
# Out:
#                           TwADR-L AskAPatient
# Unique Phrases                616        2665
# Unique Labels                  76         233
# Unique Phrase/Label Pairs     721        2686
# Phrases (multiple labels)      87          19
# Minimum examples/label          5           5
# Maximum examples/label         36         141
# Average examples/label       9.49       11.53

# %%
from sklearn.model_selection import KFold
X = np.array(df_mn)
print('\nconfirm results with scikit-learn')
kfold = KFold(n_splits = 10, shuffle = True, random_state = 4312)
for train_index, test_index in kfold.split(X):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X[train_index], X[test_index]




# create a binary classification dataset
from numpy import unique
from sklearn.datasets import make_classification
# generate 2 class dataset
X, y = make_classification(n_samples=1000, n_classes=2, weights=[0.99, 0.01], flip_y=0, random_state=1)
# summarize dataset
classes = unique(y)
total = len(y)
for c in classes:
	ex = len(y[y==c])
	percent = ex / total * 100
	print('> Class=%d : %d/%d (%.1f%%)' % (c, ex, total, percent))
# Out:
# confirm results with scikit-learn
# TRAIN: [   0    1    2 ... 2683 2684 2685] TEST: [  28   29   40   46   63   69   75   85  106  131  142  148  156  158
#   169  172  177  182  190  208  226  228  243  253  265  267  275  286
#   311  317  326  331  334  336  339  341  351  356  362  363  380  386
#   405  408  411  415  427  473  484  503  510  512  526  539  543  553
#   554  557  565  570  586  595  603  609  616  631  643  666  714  717
#   734  757  762  797  804  827  842  858  860  874  883  890  909  929
#   932  935  942  953  971  976  986  996 1018 1019 1048 1065 1070 1080
#  1088 1091 1092 1104 1105 1114 1119 1139 1146 1150 1153 1174 1176 1185
#  1188 1220 1223 1274 1293 1306 1310 1311 1314 1317 1321 1322 1324 1359
#  1366 1373 1381 1388 1392 1399 1406 1417 1442 1463 1473 1488 1493 1495
#  1496 1497 1499 1503 1505 1510 1521 1536 1548 1570 1573 1579 1580 1582
#  1603 1606 1608 1626 1628 1645 1649 1654 1655 1662 1667 1670 1701 1702
# ...
